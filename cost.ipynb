# %%
dependencies={

  "Editing": {
      "cost": 27,
  "description": 
  """components:
  - panel  3d
  - draw (837 + 178) 4d
  - attribute (257 + 123) 3d
  - create feature (335) 3d
  - create regular polygon from click (222) 3d
  - edit feature selector (281 + 38) 3d
  - export feature (234) 3d
  - editing/EditFeatureComponent (1533 + 123) 5d""",
  "depends on": [
   "misc/ngeoEventHelper",
   "misc/FeatureHelper",
   "map/LayerHelper",
   "misc/ToolActivateMgr",
   "layertree/TreeManager",
   "datasource/fileGroupModule",
   "theme/Themes",
   "misc/ngeo-datetimepicker",
   "misc/ngeo-btn",
   "message/ngeo-modal",      
    "editing/ngeo-exportfeatures",
    "editing/Snapping",
      "editing/EnumerateAttribute",
      "misc/UnitPrefix",
  ]},
  "misc/UnitPrefix": {
  "depends on": ["misc/filter"]
  },
  "WFS permalink": {
      "cost": 0,
      "description": "",
      "depends on": ["statemanager/WfsPermalink"]
  },
      
  
  
  "Drawing": {
      "cost": 16,
      "description":
"""components:
- panel  3d
- draw (260) 3d
- draw feature options (517 + 28) 4d
- feature style (334 + 170) 4d
directives:
- text (79) 1d""",
  "depends on": [
   "misc/FeatureHelper",
   "editing/Snapping",
   "misc/ToolActivateMgr",
   "misc/ngeo-btn-group",
   "misc/ngeo-btn",
   "measure/ngeo-measurelength",
   "measure/ngeo-measurearea",
   "measure/ngeo-measureazimut",
   "editing/ngeo-exportfeatures",
   "misc/ngeo-colorpicker",
"draw/ngeo-drawfeature",
"draw/ngeo-drawpoint",
"draw/ngeo-drawrectangle",
  ]},
  
  "Filter": {
      "cost": 12,
      "description":
  """components:
  - panel  3d
  - filter (536 + 103) 4d
  - rule (1064 + 241) 5d""",
  "depends on": [
   "query/MapQuerent",
   "misc/ngeo-date-picker",
   "draw/ngeo-drawfeature",
   "misc/ngeo-btn",
   "misc/ngeo-btn-group",
   "draw/ngeo-drawpoint",
   "measure/ngeo-measurelength",
   "measure/ngeo-measurearea",
   "measure/ngeo-measureazimut",
   "draw/ngeo-drawrectangle",
   "draw/ngeo-drawfeature",
   "misc/FeatureHelper",
   "misc/ToolActivateMgr",
   "misc/WMSTime",
      "filter/RuleHelper"
  ]},
  
  "Search": {
      "cost": 10,
      "description": 
  """components:
  - panel  1d
  - search (1045 + 30) 4j
  directive:
  - search (231) 2j
  service:
  - createGeoJSONBloodhound + createLocationSearchBloodhound 1j
  - full text search (89) 2j""",
  "depends on":[
   "layertree/TreeManager",
   "statemanager/Location",
   "message/ngeo-popover",
  ]},
  
  "Print": {
      "cost": 11,
      "description":
  """components:
  - panel  3d
  - print (1373 + 215) 5d
  service:
  - print (592) 2d
  - utils (156) 1d""",
  "depends on": [
   "map/LayerHelper",
   "query/MapQuerent",
   "theme/Themes",
   "datasource/ExternalDataSourcesManager",
  ]},
  
  "Permalink": {
      "cost": 2,
      "description": "pnael",
      "depends on": ["permalink/share", "permalink/service", "permalink/ShareService"]
  },
  "permalink/share": {
      "cost": 3,
      "description": "(231 + 89)",
      "depends on": [
     "statemanager/Location",
     "permalink/ShareService",
      ]},
  "permalink/service": {
  "cost": 5,
      "description": "(1970)",
      "depends on": [
     "misc/debounce",
     "misc/EventHelper",
     "statemanager/Service",
     "statemanager/Location",
     "datasource/LayerBeingSwipe",
     "datasource/Manager",
     "misc/WMSTime",
          "map/BackgroundLayerMgr",
          "misc/FeatureHelper",
          "query/Querent",
          "datasource/ExternalDataSourcesManager",
          "objectediting/Manager",
          "theme/Manager",
          "layertree/TreeManager",
          "statemanager/WfsPermalink",
          "misc/AutoProjection",
      ]},
  "permalink/ShareService": {
      "cost": 1,
      "description": "(149)"
  },
  "Background Layer"    : {
      "cost": 2,
      "description" : "panel",
      "depends on": [
          "backgroundlayerselector/selector",
      ]
  },
  "backgroundlayerselector/selector": {
      "cost": 2,
      "description": "(278 + 24)",
      "depends on": [
     "map/BackgroundLayerMgr",
     "theme/Themes",
      ]
  },
    "editing/ngeo-exportfeatures": {
      "cost": 3,
      "description": "(234)",
      "depends on": ["misc/FeatureHelper"
      ]
    },
    "editing/Snapping": {
      "cost": 3,
      "description": "(897)",
      "depends on": [
          "datasource/fileGroupModule",
          "theme/Themes",
          "layertree/TreeManager",
      ]
    },
"draw/ngeo-drawfeature":  {
    "cost": 1,
    "description": "(140)",
    "depends on": [],
},
"draw/ngeo-drawpoint":  {
    "cost": 1,
    "description": "(80)",
    "depends on": [],
},
"draw/ngeo-drawrectangle":  {
    "cost": 1,
    "description": "(95)",
    "depends on": [],
},
    
"datasource/ExternalDataSourcesManager": {
  "cost": 2,
  "description": "(777)",
  "depends on": [
"datasource/fileGroupModule",
      "datasource/DataSources",
      "misc/File",
      "map/LayerHelper",
      "datasource/FileGroup",
      "datasource/WMSGroup",
  ],
},
"datasource/LayerBeingSwipe": {
  "cost": 0,
  "description": "-",
  "depends on": [
  ],
},
"datasource/Manager": {
  "cost": 2,
  "description": "(1132)",
  "depends on": [
      "theme/Themes",
      "layertree/TreeManager",
      "map/BackgroundLayerMgr",
      "datasource/DataSources",
      "map/LayerHelper",
      "filter/RuleHelper",
      "misc/WMSTime",
      "datasource/WFSAliases",
  ],
},
"datasource/fileGroupModule": {
  "cost": 0,
  "description": "(47)",
  "depends on": [
  ],
},
"layertree/TreeManager": {
  "cost": 2,
  "description": "(809)",
  "depends on": [
      "map/LayerHelper",
      "theme/Themes",
      "statemanager/Service",
      "permalink/Permalink"
  ],
},
"map/BackgroundLayerMgr": {
  "cost": 1,
  "description": "(254)",
  "depends on": [
  ],
},
"map/LayerHelper": {
  "cost": 2,
  "description": "(726)",
  "depends on": [
  ],
},
"measure/ngeo-measurearea": {
  "cost": 2,
  "description": "(96)",
  "depends on": ["misc/UnitPrefix"
  ],
},
"measure/ngeo-measureazimut": {
  "cost": 2,
  "description": "(133)",
  "depends on": ["misc/UnitPrefix", "misc/filter"
  ],
},
"measure/ngeo-measurelength": {
  "cost": 2,
  "description": "(113)",
  "depends on": [
      "misc/UnitPrefix",
  ],
},
"message/ngeo-modal": {
  "cost": 3,
  "description": "(206)",
  "depends on": [

  ],
},
"message/ngeo-popover": {
  "cost": 4,
  "description": "(200)",
  "depends on": [

  ],
},
"misc/EventHelper": {
  "cost": 1,
  "description": "(92)",
  "depends on": [
  ],
},
"misc/FeatureHelper": {
  "cost": 3,
  "description": "(1670)",
  "depends on": [
  ],
},
"misc/ToolActivateMgr": {
  "cost": 2,
  "description": "(204)",
  "depends on": [
  ],
},
"misc/WMSTime": {
  "cost": 2,
  "description": "(137)",
  "depends on": [
      "misc/filter"
  ],
},
"misc/debounce": {
  "cost": 0,
  "description": "done in debounce2",
  "depends on": [
  ],
},
"misc/ngeo-btn": {
  "cost": 2,
  "description": "(217)",
  "depends on": [  ],
},
"misc/ngeo-btn-group": {
  "cost": 0,
  "description": "()",
  "depends on": ["misc/ngeo-btn"],
},
"misc/ngeo-colorpicker": {
  "cost": 2,
  "description": "(160 + 11)",
  "depends on": [

  ],
},
"misc/ngeo-date-picker": {
  "cost": 2,
  "description": "(286 + 26)",
  "depends on": [  ],
},
"misc/ngeo-datetimepicker": {
  "cost": 1,
  "description": "(107)",
  "depends on": [  ],
},
"misc/ngeoEventHelper": {
  "cost": 0,
  "description": "-",
  "depends on": [  "misc/EventHelper"],
},
"query/MapQuerent": {
  "cost": 2,
  "description": "(384)",
  "depends on": [
    "datasource/DataSources",
    "datasource/Helper",
    "misc/FeatureHelper",
    "query/Querent",
  ],
},
"statemanager/Location": {
  "cost": 2,
  "description": "(393)",
  "depends on": [
  ],
},
"statemanager/Service": {
  "cost": 2,
  "description": "(207)",
  "depends on": [
"statemanager/Location"
  ],
},
"theme/Themes": {
  "cost": 2,
  "description": "(770)",
  "depends on": [
"map/LayerHelper", "statemanager/Location"
  ],
},
    

"datasource/DataSources": {
  "cost": 2,
  "description": "(208)",
  "depends on": [],
},    
"datasource/Helper": {
  "cost": 2,
  "description": "(325)",
  "depends on": [
      "datasource/DataSources",
      "query/Querent",
      "editing/EnumerateAttribute"
  ],
},    
"datasource/WFSAliases": {
  "cost": 1,
  "description": "(76)",
  "depends on": ["datasource/Helper"],
},    
"datasource/FileGroup": {
  "cost": 0,
  "description": "(127)",
  "depends on": [],
},    
"datasource/WMSGroup": {
  "cost": 0,
  "description": "(233)",
  "depends on": [],
},    
"filter/RuleHelper": {
  "cost": 2,
  "description": "(744)",
  "depends on": ["misc/FeatureHelper", "misc/WMSTime"],
},    
"misc/File": {
  "cost": 2,
  "description": "(160)",
  "depends on": [],
},    
"permalink/Permalink": {
  "cost": 0,
  "description": "-",
  "depends on": ["permalink/service"],
},    
"query/Querent": {
  "cost": 2,
  "description": "(1195)",
  "depends on": ["filter/RuleHelper", "misc/WMSTime"],
},    
    "editing/EnumerateAttribute": {
    "cost": 2,
        "description": "(84)"
    },
"misc/AutoProjection": {
    "cost": 1,
    "description": "(152)",
    "depends on": []
},
"misc/filter": {
    "cost": 2,
    "description": "(577)",
    "depends on": []
},
"objectediting/Manager": {
    "cost": 2,
    "description": "(182)",
    "depends on": ["editing/EditFeature", "statemanager/Location"]
},
"statemanager/WfsPermalink": {
    "cost": 2,
    "description": "(380)",
    "depends on": []      
},
"theme/Manager": {
    "cost": 2,
    "description": "(193)",
    "depends on": ["layertree/TreeManager", "statemanager/Service"]
},    
    "editing/EditFeature": {
    "cost": 2,
    "description": "(169)",
        "depends on": [
        ]
    }
}

# %%
base_names = set()
for name, item in dependencies.items():
    if "/" not in name:
        base_names.add(name)
        print(name)
print('='*20)

result = set()
for name, item in dependencies.items():
    for depends in item.get("depends on", []):
        if depends not in dependencies:
            result.add(depends)
print("\n".join(sorted(result)))
# Out:
# Editing
# WFS permalink
# Drawing
# Filter
# Search
# Print
# Permalink
# Background Layer
# ====================

# %%
def apply(path):   
    node = dependencies[path[-1]]
    node.setdefault('use by', set()).add(path[0])
    for depends in node.get("depends on", []): 
        if depends not in path:
            apply([*path, depends])

for name in base_names:
    apply([name])

# %%
def do(name):
    commons = {}
    commons_pkg = {}
    own = 0
    total = 0
    for nname, node in dependencies.items():
        if "use by" not in node or name not in node['use by']:
            continue
        else:
            total += node.get('cost', 0)
            if len(node['use by']) ==1:
                own += node.get('cost', 0)
            else:
                for cname in node['use by']:
                    if cname == name:
                        continue
                    commons.setdefault(cname, 0)
                    commons[cname] += node.get('cost', 0)
                    commons_pkg.setdefault(cname, []).append(nname)
    print("="*30)
    print(f"{name}: {total}d (own: {own}d, other: {total - own}d)")
    for cname, cost in commons.items():
        pkg = ", ".join(commons_pkg[cname])
        #print()
        #print(f"Shared with {cname}: {cost} ({pkg})")
        print(f"Shared with {cname}: {cost}d")
            

for name in base_names:
    do(name)
# Out:
# ==============================
# Filter: 46d (own: 14d, other: 32d)
# Shared with Editing: 21d
# Shared with Drawing: 30d
# Shared with Print: 19d
# Shared with Permalink: 17d
# Shared with Search: 17d
# ==============================
# Print: 40d (own: 11d, other: 29d)
# Shared with Drawing: 27d
# Shared with Permalink: 27d
# Shared with Search: 27d
# Shared with Editing: 27d
# Shared with Background Layer: 6d
# Shared with Filter: 19d
# ==============================
# Drawing: 87d (own: 18d, other: 69d)
# Shared with Filter: 30d
# Shared with Editing: 60d
# Shared with Permalink: 50d
# Shared with Search: 50d
# Shared with Print: 27d
# Shared with Background Layer: 7d
# Shared with WFS permalink: 2d
# ==============================
# Permalink: 56d (own: 6d, other: 50d)
# Shared with Search: 50d
# Shared with Editing: 50d
# Shared with Drawing: 50d
# Shared with Print: 27d
# Shared with Background Layer: 7d
# Shared with Filter: 17d
# Shared with WFS permalink: 2d
# ==============================
# Search: 64d (own: 14d, other: 50d)
# Shared with Permalink: 50d
# Shared with Editing: 50d
# Shared with Drawing: 50d
# Shared with Print: 27d
# Shared with Background Layer: 7d
# Shared with Filter: 17d
# Shared with WFS permalink: 2d
# ==============================
# Editing: 91d (own: 31d, other: 60d)
# Shared with Filter: 21d
# Shared with Drawing: 60d
# Shared with Permalink: 50d
# Shared with Search: 50d
# Shared with Print: 27d
# Shared with Background Layer: 7d
# Shared with WFS permalink: 2d
# ==============================
# WFS permalink: 2d (own: 0d, other: 2d)
# Shared with Drawing: 2d
# Shared with Permalink: 2d
# Shared with Search: 2d
# Shared with Editing: 2d
# ==============================
# Background Layer: 11d (own: 4d, other: 7d)
# Shared with Drawing: 7d
# Shared with Permalink: 7d
# Shared with Search: 7d
# Shared with Editing: 7d
# Shared with Print: 6d

# %%
total = 0
for name, node in dependencies.items():
    total += node.get("cost", 0)
print(total)
# Out:
# 169
